# %%
print("nishazareentaj 26th june 2026")
# Out:
# nishazareentaj 26th june 2026

# %%
def is_palindrome(j):
    # Remove spaces and convert to lowercase for a fair comparison
    cleaned = ''.join(j.split()).lower()
    # Check if the cleaned string is the same forwards and backwards
    return cleaned == cleaned[::-1]

# Let's test it out!
print(is_palindrome("radar"))  # This should return True
print(is_palindrome("hello")) 
print(is_palindrome("nissin")) # This should return False
print("")
# Out:
# True
# False
# True

# %%
def reverse_string(text):
    # Remove spaces and convert to lowercase if you want
    cleaned = ''.join(text.split()).lower()
    # Reverse it using slicing
    return cleaned[::-1]

# Take input from user
user_input = input("Enter a string: ")
print(user_input)
reversed_text = reverse_string(user_input)
print("Reversed string:", reversed_text)
print("this was a play with strings its an amazing concept suported by python")
# Out:
# kolkar
# Reversed string: raklok
# this was a play with strings its an amazing concept suported by python

# %%
print("""The provided code stub reads two integers,  and , from STDIN.
Add logic to print two lines. The first line should contain the result of integer division,  // . 
The second line should contain the result of float division,  / 
""")
a=int(input("enter first number:"))
b=int(input("enter second number:"))
print(a//b)
print(a/b)
# Out:
# The provided code stub reads two integers,  and , from STDIN.
# Add logic to print two lines. The first line should contain the result of integer division,  // .
# The second line should contain the result of float division,  /
#
# 1
# 1.0

# %%
print("write a function to return addition, subraction,multiplication,division,floor division of \n two user input numbers")
num1=int(input("enter first number:"))
num2=int(input("enter second number:"))
print(num1,num2)
print(f"addition:{num1+num2},subraction:{num1-num2},multiplication:{num1*num2},division:{num1//num2},floor division:{num1//num2}")
'''def nisha():
    addition = num1 + num2
    subtraction = num1 - num2
    multiplication = num1 * num2
    division = num1 / num2
    floor_division = num1 // num2
    print(f"addition of two numbers:{addition} \n, subbration of two numbers:{subtraction} \n, multiplication of two numbers:{multiplication} \n, division of two numbers:{division} \n, floor division of two numbers:{floor_division}")

    
nisha()'''
# Out:
# write a function to return addition, subraction,multiplication,division,floor division of
#  two user input numbers
# 2210 221027
# addition:223237,subraction:-218817,multiplication:488469670,division:0,floor division:0
# 'def nisha():\n    addition = num1 + num2\n    subtraction = num1 - num2\n    multiplication = num1 * num2\n    division = num1 / num2\n    floor_division = num1 // num2\n    print(f"addition of two numbers:{addition} \n, subbration of two numbers:{subtraction} \n, multiplication of two numbers:{multiplication} \n, division of two numbers:{division} \n, floor division of two numbers:{floor_division}")\n\n\nnisha()'

# %%
print("if n is odd print weird")
n=int(input("enter number:").strip())
for n in range(5):
    if n%2==0:
        print("not weird")
    else:
        print("weird")
# Out:
# if n is odd print weird
# not weird
# weird
# not weird
# weird
# not weird

# %%
"""write a python function that takes a string and returns the first non repeating character if all characters repeat return none"""
def nisha(s:str):
    for char in s:
        if s.count(char)==1:
            return char
    return None
print(nisha("nisha"))
print(nisha("aabbcc"))
print(nisha("ABC"))
# Out:
# n
# None
# A

# %%
"""write a function that takes list of integers and returns a new list witth all duplicates removed sorted in ascendind order"""
def removingduplicates(numbers):
    return sorted(list(set(numbers)))
result=removingduplicates([4,4,5,5,8,9,9,2,6,6,7,1])
print(result)
# Out:
# [1, 2, 4, 5, 6, 7, 8, 9]
